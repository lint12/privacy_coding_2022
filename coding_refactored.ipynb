# %%
import psycopg2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

# %%
# Credentials
DB_NAME = 'documentcoder'
DB_USER = 'postgres'
DB_PASS = 'save'

# %%
# CONNECTION IS ESTABLISHED IF NOTHING RETURNS 
conn = psycopg2.connect(dbname=DB_NAME, user=DB_USER, password=DB_PASS)

# %%
# Create Cursor to execute statements
cur = conn.cursor()

# %%
cur.execute("""
            SELECT x->'label', x->'questions'
            FROM api_coding, jsonb_array_elements(categories) as x
            """)

# %%
api_codings = cur.fetchall()
api_codings
# Out:
# [('CCPA',
#   [{'id': 'v72.1_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA- Notice',
#     'description': 'Is the CCPA section in a separate link (as opposed to in the same privacy policy?)',
#     'questionOptions': [{'meta': {},
#       'label': "[0] no, it's part of the same privacy policy",
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': "[1] yes, it's on a separate link or separate document",
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': '[.] N/A -there is no CCPA section or CCPA reference in the contract',
#       'value': '.',
#       'details': ''}]},
#    {'id': 'v72.2_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA- Notice',
#     'description': 'Does PP states firms\' CCPA policy only applies to California residents? (for example,  Tinder\'s  states that "This California section supplements the Privacy Policy and applies solely to California consumers (excluding our personnel). The Table below describes how we process California consumers’ personal information (excluding our personnel), based on definitions laid out in the California Consumer Privacy Act ("CCPA")." ',
#     'questionOptions': [{'meta': {},
#       'label': '[0] no,',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': '[1] yes,', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': '[.] N/A -there is no CCPA section or CCPA reference in the contract',
#       'value': '.',
#       'details': ''}]},
#    {'id': 'v73_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-13'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Notice',
#     'description': 'Directs CA Residents to that section when describing general (non-california exclusive) data practices?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': '[.] N/A -there is no CCPA section or CCPA reference in the contract',
#       'value': '.',
#       'details': ''}]},
#    {'id': 'v74_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Notice',
#     'description': 'Personal Information Request: Offers CA residents an opportunity to request all information shared with third parties in the last year?',
#     'questionOptions': [{'meta': {},
#       'label': 'no or does not disclose',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': '[.] -N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v75_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Notice',
#     'description': 'Offers California residents a direct link via which to contact site and request information?',
#     'questionOptions': [{'meta': {},
#       'label': 'contact info in different section,',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'contact info in same section,',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'direct link included in same section)',
#       'value': '2',
#       'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v76_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Notice',
#     'description': 'Data requests are explicitly free of charge?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v77_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Data Sharing',
#     'description': 'Does the PP list the categories of personal information sold in the past 12 months?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v78_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Data Choices',
#     'description': 'PP identifies at least two methods for submitting a personal information or erasure request, in accordance with CCPA?(These  must include, at a minimum, a web page and a toll-free telephone number)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'two methods identified,',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'one method identified',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'two methods identified, but different from web page and toll-free number [state which those are in comments, and please highlight in PP]',
#       'value': '3',
#       'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v72_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Notice',
#     'description': 'Has California Privacy Rights Section that explains all rights afforded under the CCPA? (The right to request disclosure of  business’ data collection and sales practices , the categories of personal information collected, the source of the information,  use of the information and, if the information was disclosed or sold to third parties, the categories of personal information disclosed or sold to third parties and the categories of third parties to whom such information was disclosed or sold; The right to request a copy of the specific personal information collected about them during the 12 months before their request (together with right #1, a “personal information request”); The right to have such information deleted (with exceptions); he right to request that their personal information not be sold to third parties, if applicable; and The right not to be discriminated against because they exercised any of the new rights.]',
#     'questionOptions': [{'meta': {},
#       'label': 'No',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes, fully compliant',
#       'value': '1',
#       'details': ''},
#      {'meta': {}, 'label': 'partial compliance', 'value': '2', 'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v80_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'CCPA - Opt Out',
#     'description': 'Firm offers the right of opt-out of selling personal information to third parties with a visible, direct link to "Do Not Sell My Personal Information."',
#     'questionOptions': [{'meta': {},
#       'label': 'no mention',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': "mentions the right but explains why it's not available/not applicable (e.g., firm does not sell information to third parties)",
#       'value': '2',
#       'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]}]),
#  ('Notice',
#   [{'id': 'v3_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Access',
#     'description': 'Is there layered notice or short notice? (i.e., are the key PP terms giving users the gist of the contract summarized on top of the document or somewhere noticeable? Table of Contents does not qualify)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v10.1_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Type of Data Collected',
#     'description': 'Does the company have a cookie policy? (note "Yes" if the company has a stated cookie policy (e.g., a section in the privacy policy explaining its cookie policy) or offers link to a document with it, or if there is an attached cookie policy in the coding tool)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v10.2_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-06'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Type of Data Collected',
#     'description': 'Does the company explicitly state they use tracking elements other than cookies? (e.g. "local storage cookies", "browser fingerprints")?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': "'does not disclose'",
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v11.1_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'Note that Article 51 does automatically label a photograph as biometric data "The processing of photographs should not systematically be considered to be processing of special categories of personal data as they are covered by the definition of biometric data only when processed through a specific technical means allowing the unique identification or authentication of a natural person."'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Type of Data Collected',
#     'description': 'Biometric Information Collected and Stored? (e.g., facial scans, fingerprints, facial patterns, voice or typing cadence.)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': "'does not disclose'",
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v12_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'ccpa_info': 'CCPA defines business purpose as "Business purpose” means the use of personal information for the business’s or a service provider’s operational purposes, or other notified purposes, provided that the use of personal information shall be reasonably necessary and proportionate to achieve the operational purpose for which the personal information was collected or processed or for another operational purpose that is compatible with the context in which the personal information was collected. Business purposes are:\n(1) Auditing related to a current interaction with the consumer and concurrent transactions, including, but not limited to, counting ad impressions to unique visitors, verifying positioning and quality of ad impressions, and auditing compliance with this specification and other standards.\n(2) Detecting security incidents, protecting against malicious, deceptive, fraudulent, or illegal activity, and prosecuting those responsible for that activity.\n(3) Debugging to identify and repair errors that impair existing intended functionality.\n(4) Short-term, transient use, provided that the personal information is not disclosed to another third party and is not used to build a profile about a consumer or otherwise alter an individual consumer’s experience outside the current interaction, including, but not limited to, the contextual customization of ads shown as part of the same interaction.\n(5) Performing services on behalf of the business or service provider, including maintaining or servicing accounts, providing customer service, processing or fulfilling orders and transactions, verifying customer information, processing payments, providing financing, providing advertising or marketing services, providing analytic services, or providing similar services on behalf of the business or service provider.\n(6) Undertaking internal research for technological development and demonstration.\n(7) Undertaking activities to verify or maintain the quality or safety of a service or device that is owned, manufactured, manufactured for, or controlled by the business, and to improve, upgrade, or enhance the service or device that is owned, manufactured, manufactured for, or controlled by the business."',
#       'gdpr_info': "This would satisfy Article 6's legitimacy requirement.\nArt 6 requires that a privacy policy include a lawful basis to explain why the company needs to process personal information (consent is one lawful basis) [Article 6 – Lawfulness of processing\n\nProcessing shall be lawful only if and to the extent that at least one of the following applies:\nprocessing is necessary for the performance of a contract to which the data subject is party or in order to take steps at the request of the data subject prior to entering into a contract;\n\n",
#       'threshold': '2020-06-15'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr', 'ccpa']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Use of Data',
#     'description': 'Company commits that PII will be used internally only for business purposes ( e.g., effecting, administering, or enforcing a transaction, sending future correspondence to user, research, internal database compilation, servicing website)? [Article 4 of the GDPR, personal data is "any information relating to an identified or identifiable natural person. In general, internal business purposes involve use of data for purposes that are in the service of the user)[Advertising is not considered internal business purposes; Article 6 of GDPR defines as legitimiate or "business purpose  processing is necessary for the performance of a contract to which the data subject is party or in order to take steps at the request of the data subject prior to entering into a contract;\n\n',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'yes, but there are other terms in the policy that conflict with such commitment',
#       'value': '2',
#       'details': ''}]},
#    {'id': 'v13_2020.1',
#     'info': '',
#     'meta': {'info': {'threshold': '2020-07-12'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Exactly One', 'value': 'singleselect'},
#     'label': 'Notice - Use of Data',
#     'description': 'Company commits to use PII (personally identifiable information) data only for stated context specific purposes. These are purposes that a user would expect in the context of the service provided.  E.g., what you post to a message board must be made public for a message board to work)?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'yes, but there are other terms in the policy that conflict with such commitment',
#       'value': '2',
#       'details': ''}]},
#    {'id': 'v17_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - 3rd parties',
#     'description': 'Third party tracking: site allows third parties to place advertisements that may track user behavior?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': "'does not disclose'",
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v18_2020',
#     'info': '',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Exactly One', 'value': 'singleselect'},
#     'label': 'Notice - 3rd parties',
#     'description': 'PP identifies third party recipients of shared or sold data? (General question)',
#     'questionOptions': [{'meta': {},
#       'label': 'gen\'l ID ("trusted 3rd parties")',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'specific/named entity or named category of third party',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'Does not disclose',
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v19_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - 3rd parties',
#     'description': 'PP defines words such as "affiliates" or "third parties" if it uses them? (i.e.. the policy includes definitions of what it means by these categories; examples are not enough to classify as a definition)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'n/a', 'value': '.', 'details': ''}]},
#    {'id': 'v32_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Change of Terms',
#     'description': 'PP has a Change of Terms (COT) provision that explicitly or implicitly allows entity to change agreement?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v35_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Change of Terms',
#     'description': 'PP requires user to explicitly assent to material changes?',
#     'questionOptions': [{'meta': {},
#       'label': "no/ does't say",
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'N/A', 'value': '.', 'details': ''}]},
#    {'id': 'v36_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Change of Terms',
#     'description': 'PP states that material changes are retroactive?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes (applies to data made before the change)',
#       'value': '1',
#       'details': ''}]},
#    {'id': 'v48_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Use of Data',
#     'description': 'PP provides notice of data procedures if company is sold or otherwise ceases to exist (e.g., goes bankrupt)?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]}]),
#  ('Sharing',
#   [{'id': 'v20_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-29'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Sharing - privacy practices',
#     'description': 'Are affiliates and/or subsidiaries (specifically) bound by the same privacy policy, confidentiality agreements, or have a contract with firm outlining how data will be used and secured?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'does not disclose', 'value': 'DND', 'details': ''},
#      {'meta': {}, 'label': 'n/a', 'value': '.', 'details': ''}]},
#    {'id': 'v21_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-29'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Sharing - privacy practices',
#     'description': 'Are contractors/service providers (under CCPA)/processors (under GDPR)  (e.g., payment process companies) bound by either the same privacy policy, confidentiality agreements, or have a contract with firm outlining how data will be used and secured?  (CCPA, GDPR compliance requirement)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'does not disclose', 'value': 'DND', 'details': ''},
#      {'meta': {}, 'label': 'n/a', 'value': '.', 'details': ''}]},
#    {'id': 'v22_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-22'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Sharing - privacy practices',
#     'description': 'Are third parties bound by the same privacy policy?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'does not disclose', 'value': 'DND', 'details': ''},
#      {'meta': {},
#       'label': 'n/a [this would be applicable if, for example, the company did not share information with third parties]',
#       'value': '.',
#       'details': ''}]},
#    {'id': 'v27_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-26'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Sharing - 3rd Parties',
#     'description': 'Entity performs due diligence to ensure legitimacy of 3rd parties that have access to data?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v28_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Sharing - 3rd Parties',
#     'description': 'Entity has contract with 3rd parties (excluding processors/service providers)  establishing how disclosed data can be used?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'does not disclose', 'value': 'DND', 'details': ''},
#      {'meta': {}, 'label': 'n/a', 'value': '.', 'details': ''}]},
#    {'id': 'v29_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Sharing - 3rd Parties',
#     'description': "PP provides links to relevant 3rd parties' PP's? (sometimes the PP includes links to third party privacy policies, usually when it states that any engagement with third parties will be governed by third party privacy policies",
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'n/a (in cases where there are no relationships with third parties of any sort)',
#       'value': '.',
#       'details': ''}]},
#    {'id': 'v31_2020',
#     'info': '',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Exactly One', 'value': 'singleselect'},
#     'label': 'Sharing - Consent',
#     'description': "What is consent mechanism for sharing/selling PII or sensitive information to entities that aren't service providers (except for the purpose of effecting, administering, or enforcing a transaction, sending future correspondence to user, research, internal database compilation, servicing website)?",
#     'questionOptions': [{'meta': {},
#       'label': 'mandatory or does not disclose',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'opt-out  [The default is for the user to share PII with third parties, but the PP gives the user the opportunity to opt out]',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'opt-in [User must consent before data can be shared with or collected/used by third party]',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'N/A (applicable if firm does not engage in this practice)',
#       'value': '.',
#       'details': ''}]}]),
#  ('User Control',
#   [{'id': 'v37_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'User Control - Accuracy',
#     'description': "Can users can adjust privacy settings?  [Double check on the website; directing user to control cookies via browser setting doesn't count]",
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v38_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-21'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'User Control - Accuracy',
#     'description': 'Are users allowed to access and correct/update personal data collected?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'Can access data', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'Can access and correct data',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'Can access and correct data, and 3rd parties notified of correction',
#       'value': '3',
#       'details': ''}]},
#    {'id': 'v37.2_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': ' GDPR states that “every reasonable step must be taken” to erase or rectify data that is inaccurate or incomplete. Individuals have the right to request that inaccurate or incomplete data be erased or rectified within 30 days',
#       'threshold': '2020-06-21'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'User Control - Accuracy',
#     'description': 'Can the user request that incorrect data be either rectified, updated, or erased?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes, within 30 days [in compliance with GDPR]',
#       'value': '1',
#       'details': ''},
#      {'meta': {}, 'label': 'yes, no time limit', 'value': '2', 'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v39_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'User Control - User Control',
#     'description': 'Can user request that information be deleted or anonymized? ',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes (partial) [User can delete/anonymize account, but the company/organization may continue to keep some of the user’s data]',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes (full) [User can delete account and all of the user’s information is removed from company/organization’s servers/databases.]',
#       'value': '2',
#       'details': ''}]},
#    {'id': 'v40_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-21'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'User Control - Ownership',
#     'description': 'Ownership Rights of User Information Provided (look in terms of use)',
#     'questionOptions': [{'meta': {},
#       'label': 'Company owns data',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': "User owns data, but licenses data to entity in a non-exclusive, royalty-free, form, with no right to compensation for company's use of the data",
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'User owns the data but the license is not as broad as in [1[, where the company can use, share, and commercialize data/proprietary media as it sees fit.',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v47_2020.1',
#     'info': '',
#     'meta': {'info': {'threshold': '2020-07-04'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Exactly One', 'value': 'singleselect'},
#     'label': 'User Control - Termination',
#     'description': 'What happens to data if entity ceases to exist or is acquired?',
#     'questionOptions': [{'meta': {},
#       'label': 'sold w/company or otherwise distributed/disclosed [e.g., when the company liquidates and the assets are sold piecemal]',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'sold but given continued protection under same PP; or transferred to acquiring entity',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'destroyed, anonymized, etc.',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'user is given choice as to what happens with data',
#       'value': '3',
#       'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v49_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'User Control - Termination',
#     'description': 'If company is sold or goes bankrupt, user is given choice as to what happens to their data?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v51_2020',
#     'info': '',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Exactly One', 'value': 'singleselect'},
#     'label': 'User Control  - Termination',
#     'description': 'If user quits site, what happens to personal data?',
#     'questionOptions': [{'meta': {},
#       'label': 'retained and treated as if user is still using service',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'Retained  but modified',
#       'value': '1',
#       'details': ''},
#      {'meta': {}, 'label': 'deleted/anonymized', 'value': '2', 'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]}]),
#  ('Security',
#   [{'id': 'v41_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security - Accuracy',
#     'description': 'PP/TOU guarantees data accuracy (must say the word data accuracy for this to be relevant)?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v42_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security  - Accuracy',
#     'description': 'PP specifies reasonable procedures in place to ensure accuracy?  (Even a little procedure qualifies, please highlight relevant text)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v43_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security  - Accuracy',
#     'description': 'PP reserves right to disclose protected information to comply with law/prevent crime?',
#     'questionOptions': [{'meta': {},
#       'label': "no/doesn't say",
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v44_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security  - Enforcement',
#     'description': 'PP reserves right to disclose protected information to protect its own rights?',
#     'questionOptions': [{'meta': {},
#       'label': "no/doesn't say",
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v45_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security  - Notice',
#     'description': 'Users will be given notice of government requests for information about the user.',
#     'questionOptions': [{'meta': {},
#       'label': "no/ doesn't say",
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v46_2020',
#     'info': '',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Exactly One', 'value': 'singleselect'},
#     'label': 'Security  - Notice',
#     'description': 'User will be notified of data breach?',
#     'questionOptions': [{'meta': {},
#       'label': 'no (or does not disclose)',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v53_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security  - Privacy by Design',
#     'description': "PP describes substantive privacy and security protections incorporated into entity's managerial/structural procedures (e.g., limiting the number of employees who have access to data, allowing data access only for job-related functions, assigning employees to oversee privacy issues, employing Chief Privacy Officer, requiring periodic audits)? (General question)",
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v54_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Security  - Privacy by Design',
#     'description': 'PP specifically identifies means of technological security (e.g., encryption)?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]}]),
#  ('Data Practices',
#   [{'id': 'v52_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Data Practices  - Retention',
#     'description': 'Does company have a procedure for safely disposing unused/no longer needed data?',
#     'questionOptions': [{'meta': {},
#       'label': "no or doesn't say",
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]}]),
#  ('Enforcement',
#   [{'id': 'v55_2020',
#     'info': '',
#     'meta': {'info': {'ccpa_info': 'CCPA requirement',
#       'gdpr_info': 'GDPR requirement'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr', 'ccpa']},
#     'type': {'label': 'Select Exactly One', 'value': 'multiselect'},
#     'label': 'Enforcement',
#     'description': 'PP provides means by which user can contact site with privacy concerns and/or complaints? [select all that apply]',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes, for all users', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'yes, and mentions it in accordance with CCPA [or listed under a CCPA section in PP]',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes, and mentions it in accordance with GDPR [or listed under a GDPR section in PP]',
#       'value': '3',
#       'details': ''}]},
#    {'id': 'v56_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Dispute Resolution',
#     'description': 'PP has forum selection clause? If so, which forum? (Look in TOU as well)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v57_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Dispute Resolution',
#     'description': 'PP has choice of law clause?  If so, which law? (Look in TOU as well)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v58_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Dispute Resolution',
#     'description': 'PP has arbitration clause?  (Look in TOU as well)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'consumer may choose arbitration',
#       'value': '2',
#       'details': ''}]},
#    {'id': 'v59_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Dispute Resolution',
#     'description': 'PP has class action waiver?  (Look in TOU as well)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v60_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Liability',
#     'description': 'PP disclaims liability for failure of security measures?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v61_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Oversight',
#     'description': "PP provides link to FTC's Consumer Complaint Form and/or the FTC telephone number?[this just asks if the PP mentions the FTC's consumer complaint form at all or provides links to it]",
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v62_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-06-21'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Enforcement  - Oversight',
#     'description': 'What privacy seal/certification/industry oversight organization does PP claim [other than mandatory international law (Swiss Privacy Law, etc)? [Privacy Seals are independent, third-party enforcement programs  to monitor company practices and enforce privacy policies. They are designed to provide protection to consumers by allowing Web companies to standardize privacy policies. Privacy seal programs include, among others, TRUSTe, BBBOnline, and CPA Webtrust. These are different from regulatory compliance seals, such as those that the company complies with COPPA, the Children Online Privacy Protection Act). ',
#     'questionOptions': [{'meta': {},
#       'label': '.',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'Name of certification or seal',
#       'value': '1',
#       'details': ''}]}]),
#  ('Privacy By Design',
#   [{'id': 'v63_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Privacy By Design - Oversight',
#     'description': 'PP requires periodic compliance review of structural and technological data security measures?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v64_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Privacy By Design - Oversight',
#     'description': 'PP contains self-reporting measures in case of privacy violation (to a privacy seal organization, 3rd party consultant)?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]}]),
#  ('Contract',
#   [{'id': 'PP_in_TOU',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Contract - Contract',
#     'description': 'Is the PP  incorporated by reference in the TOU?',
#     'questionOptions': [{'meta': {},
#       'label': 'yes',
#       'value': '1',
#       'details': ''},
#      {'meta': {}, 'label': 'no', 'value': '0', 'details': ''}]}]),
#  ('GDPR',
#   [{'id': 'v71_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'GDPR - Notice',
#     'description': 'PP states that it is GDPR compliant or includes section on GDPR compliance',
#     'questionOptions': [{'meta': {},
#       'label': 'yes',
#       'value': '1',
#       'details': ''},
#      {'meta': {}, 'label': 'no or no mention', 'value': '0', 'details': ''}]},
#    {'id': 'v80.2_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'GDPR - Notice',
#     'description': 'Does PP state it complies with EU-US Privacy Shield? ',
#     'questionOptions': [{'meta': {},
#       'label': '[0] no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': '[1] yes', 'value': '1', 'details': ''}]},
#    {'id': 'v80.3_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-03'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'GDPR - Notice',
#     'description': 'Does PP state that GDPR terms apply only and exclusively to EU residents?',
#     'questionOptions': [{'meta': {},
#       'label': '[0] no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': '[1] yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': '[.] N/A (no GDPR terms)',
#       'value': '.',
#       'details': ''}]},
#    {'id': 'v81_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'Article 22 – Automated individual decision-making, including profiling (The data subject shall have the right not to be subject to a decision based solely on automated processing, including profiling, which produces legal effects concerning him or her or similarly significantly affects him or her.)'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'GDPR-Automated Processes',
#     'description': "Can users object to processing or automated decision making that could impact them? (This is only applicable if company does profiling or any other automated decision making, such as algorithmic decision making, or any automated decisions that don't involve a human)",
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'not applicable', 'value': '.', 'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]},
#    {'id': 'v82_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'Article 22 – Automated individual decision-making, including profiling (The data subject shall have the right not to be subject to a decision based solely on automated processing, including profiling, which produces legal effects concerning him or her or similarly significantly affects him or her.)'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'GDPR-Automated Processes',
#     'description': 'If firm engages in automated decision making, does it provide meaningful information about the logic involved, or significance/effect of such decisions?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'not applicable', 'value': '.', 'details': ''},
#      {'meta': {},
#       'label': 'does not disclose',
#       'value': 'DND',
#       'details': ''}]}]),
#  ('COVID',
#   [{'id': 'v83_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'COVID ',
#     'description': 'Does the PP include any terms related to contact tracing, health tracking, or other terms in relationship to COVID?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]}]),
#  ('[Skip me!] Notice of Contract',
#   [{'id': 'v2_2020_txt',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {}, 'notes': 'copied from 2020', 'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice of Contract - Consent and Registration',
#     'description': 'Users are asked to manifest consent to PP when they sign up for service/site via clickwrap (i.e., Click "I agree" button or similar)?  Accepting PP through use is not manifested consent.',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {},
#       'label': 'Not applicable (e.g., there is no registration option)',
#       'value': 'N/A',
#       'details': ''}]},
#    {'id': 'v0_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'threshold': '2020-07-11'},
#      'notes': 'copied from 2020',
#      'source': []},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice of Contract- Registration and Salience',
#     'description': 'For potential registrants (i.e., when you are trying to sign up): How salient is the PP on registration page? [go to main page to check--use incognito browser and look at how PP is presented for users who want to register]',
#     'questionOptions': [{'meta': {},
#       'label': 'hyperlinked, at the bottom of the main page (Specht)',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'visibly located on the main page, but no click required to accept, and no notice that privacy policy must be agreed upon (Nguyen v. Barnes and Noble)',
#       'value': '2',
#       'details': ''},
#      {'meta': {},
#       'label': 'visible on the main page, with notice that user must agree to it, but no clicking requirement to agree (Rodman v. Safeway)',
#       'value': '3',
#       'details': ''},
#      {'meta': {},
#       'label': "visible on main page, with a “sign in” wrap that doesn't unambiguously inform the user that clicking signifies assent to Privacy Policy. (Berkson v. Gogo)",
#       'value': '4',
#       'details': ''},
#      {'meta': {},
#       'label': 'visible on main page, with a hyperlinked Privacy Policy and a requirements that the user unambiguously click on “I agree” to PP. (Fteja v. Facebook)',
#       'value': '5',
#       'details': ''},
#      {'meta': {},
#       'label': 'visible on main page, with a Privacy Policy on a scroll down box  and a requirements that the user unambiguously click on “I agree” to PP.',
#       'value': '6',
#       'details': ''},
#      {'meta': {},
#       'label': 'Registration is not an option on this site',
#       'value': '7',
#       'details': ''}]},
#    {'id': 'v1_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'The requirement of consent under Article 4 requires "any freely given, specific, informed and unambiguous indication of the data subject\'s wishes by which he or she, by a statement or by a clear affirmative action, signifies agreement to the processing of personal data relating to him or her"'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice of Contract - PP Accessibility on Site',
#     'description': 'Privacy Policy (PP) is accessible through a direct link from the homepage? [this measures what any user would see on the landig page; it measures visibility without registration or when registration is not an option]',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''}]},
#    {'id': 'v2.1_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'The requirement of consent under Article 4 requires "any freely given, specific, informed and unambiguous indication of the data subject\'s wishes by which he or she, by a statement or by a clear affirmative action, signifies agreement to the processing of personal data relating to him or her"'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice of Contract - Salience of Consent to Cookies',
#     'description': 'Are users asked to manifest unambiguous consent (such as clicking in a non-pre checked "I agree" box) to cookies and trackers when on the company\'s website?',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'other', 'value': '2', 'details': ''}]},
#    {'id': 'v2.2_2020',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'The requirement of consent under Article 4 requires "any freely given, specific, informed and unambiguous indication of the data subject\'s wishes by which he or she, by a statement or by a clear affirmative action, signifies agreement to the processing of personal data relating to him or her"'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice of Contract- Salience of Consent to Communications and Marketing',
#     'description': 'Are users asked to manifest unambiguous consent (such as clicking in a non-pre checked "I agree" box during a visit to the site) to receiving communications and marketing when on the company\'s website? (e.g., emails from the firm with promotions, etc.)',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'other', 'value': '2', 'details': ''}]},
#    {'id': 'v2.3_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'info': {'gdpr_info': 'Art 6 requires that a privacy policy include a lawful basis to explain why the company needs to process personal information (consent is one lawful basis) [Article 6 – Lawfulness of processing\n\nProcessing shall be lawful only if and to the extent that at least one of the following applies:\nthe data subject has given consent to the processing of his or her personal data for one or more specific purposes;\nprocessing is necessary for the performance of a contract to which the data subject is party or in order to take steps at the request of the data subject prior to entering into a contract;\nprocessing is necessary for compliance with a legal obligation to which the controller is subject;\nprocessing is necessary in order to protect the vital interests of the data subject or of another natural person;\nprocessing is necessary for the performance of a task carried out in the public interest or in the exercise of official authority vested in the controller;\nprocessing is necessary for the purposes of the legitimate interests pursued by the controller or by a third party, except where such interests are overridden by the interests or fundamental rights and freedoms of the data subject which require protection of personal data, in particular where the data subject is a child.\n]\n',
#       'threshold': '2020-06-22'},
#      'notes': 'copied from 2020',
#      'source': ['gdpr']},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice of Contract- Salience of Consent to processing personal information (PII)',
#     'description': 'Are users asked to manifest unambiguous consent (such as clicking in a non-pre checked "I agree" box during a visit to the site) to the collection and processing of their information? [usually in the form of a pop up window when the user is about to register for the first time]. Try using incognito window. ',
#     'questionOptions': [{'meta': {},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {}, 'label': 'yes', 'value': '1', 'details': ''},
#      {'meta': {}, 'label': 'other', 'value': '2', 'details': ''}]},
#    {'id': 'v2.4_2020.1',
#     'info': 'please select the most appropriate option',
#     'meta': {'notes': '', 'source': ''},
#     'type': {'label': 'Select Multiple', 'value': 'singleselect'},
#     'label': 'Notice - Withdrawal of Consent (GDPR)',
#     'description': 'Are users given the option of withdrawing their consent to the collection of information in any clause in the contract, or are notified of this before entering the contract? (e.g., this would be satisfied when the firm allows the user to withdraw their consent by changing their account settings, or contacting the firm identifying which types of consent user is withdrawing from --consent to collection, sharing, etc, removing permissions from apps in "settings")',
#     'questionOptions': [{'meta': {'notes': ''},
#       'label': 'no',
#       'value': '0',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes, and the clause provides an existence of the right and a summary of what that right involves',
#       'value': '1',
#       'details': ''},
#      {'meta': {},
#       'label': 'yes, but the clause offers only incomplete information about the right (e.g., by giving no detail about what that right involves, or it tells consumers they can withdraw consent but does not explain how to exercise it)',
#       'value': '2',
#       'details': ''}]}])]

# %%
coding_questions = {'labels': [], 'q_ids': [], 'q_text': [], 'q_resp': [], 'ans_vals': []}

for coding in api_codings: 
    # use coding label as key for coding_questions dict
    label = coding[0]
    for question in coding[1]: 
        for res in question['questionOptions']:
            coding_questions['labels'].append(label)
            coding_questions['q_ids'].append(question['id'])
            coding_questions['q_text'].append(question['description'])
            coding_questions['q_resp'].append(res['label'])
            coding_questions['ans_vals'].append(res['value'])

# %%
count_size = len(coding_questions['q_ids'])
count_size

df = pd.DataFrame(data={'Label': coding_questions['labels'], 'Question ID': coding_questions['q_ids'], 
                        'Question Text': coding_questions['q_text'], 'Question Response': coding_questions['q_resp'], 
                        'Answer Value': coding_questions['ans_vals'], 'Count': np.zeros((count_size,), dtype=int),
                        'Median Confidence': np.full((count_size,), -1), 
                        'Median Focus': np.zeros((count_size,), dtype=int), 
                        'Median Blur': np.zeros((count_size,), dtype=int), 
                        'FMW': np.full((count_size,), False)})

# %%
df
# Out:
#                              Label   Question ID  \
# 0                             CCPA  v72.1_2020.1
# 1                             CCPA  v72.1_2020.1
# 2                             CCPA  v72.1_2020.1
# 3                             CCPA  v72.2_2020.1
# 4                             CCPA  v72.2_2020.1
# ..                             ...           ...
# 202  [Skip me!] Notice of Contract   v2.3_2020.1
# 203  [Skip me!] Notice of Contract   v2.3_2020.1
# 204  [Skip me!] Notice of Contract   v2.4_2020.1
# 205  [Skip me!] Notice of Contract   v2.4_2020.1
# 206  [Skip me!] Notice of Contract   v2.4_2020.1
#
#                                          Question Text  \
# 0    Is the CCPA section in a separate link (as opp...
# 1    Is the CCPA section in a separate link (as opp...
# 2    Is the CCPA section in a separate link (as opp...
# 3    Does PP states firms' CCPA policy only applies...
# 4    Does PP states firms' CCPA policy only applies...
# ..                                                 ...
# 202  Are users asked to manifest unambiguous consen...
# 203  Are users asked to manifest unambiguous consen...
# 204  Are users given the option of withdrawing thei...
# 205  Are users given the option of withdrawing thei...
# 206  Are users given the option of withdrawing thei...
#
#                                      Question Response Answer Value  Count  \
# 0         [0] no, it's part of the same privacy policy            0      0
# 1    [1] yes, it's on a separate link or separate d...            1      0
# 2    [.] N/A -there is no CCPA section or CCPA refe...            .      0
# 3                                              [0] no,            0      0
# 4                                             [1] yes,            1      0
# ..                                                 ...          ...    ...
# 202                                                yes            1      0
# 203                                              other            2      0
# 204                                                 no            0      0
# 205  yes, and the clause provides an existence of t...            1      0
# 206  yes, but the clause offers only incomplete inf...            2      0
#
#      Median Confidence  Median Focus  Median Blur    FMW
# 0                   -1             0            0  False
# 1                   -1             0            0  False
# 2                   -1             0            0  False
# 3                   -1             0            0  False
# 4                   -1             0            0  False
# ..                 ...           ...          ...    ...
# 202                 -1             0            0  False
# 203                 -1             0            0  False
# 204                 -1             0            0  False
# 205                 -1             0            0  False
# 206                 -1             0            0  False
#
# [207 rows x 10 columns]

# %%
q_ids = set(coding_questions['q_ids'])

# %%
for q_id in q_ids: 
    cur.execute("""
        SELECT coding_values->%s->'values'
        FROM api_codinginstance
        WHERE coder_email != 'davidbstein@gmail.com';
        """,[q_id,])
    
    query_result = cur.fetchall()
    for value in query_result:
        if (value[0] is not None) and (bool(value[0]) != False):
            resp_val = next(iter(value[0]))
            df.loc[(df['Question ID'] == q_id) & (df['Answer Value'] == resp_val), 'Count'] += 1

# %%
def calc_median(arr): 
    return np.median(np.array(arr)) if len(arr) != 0 else 0

# %%
for q_id in q_ids:
    cur.execute("""
        SELECT coding_values->%s->'confidence'
        FROM api_codinginstance
        WHERE coder_email != 'davidbstein@gmail.com';
        """,[q_id,])

    query_res = cur.fetchall()
    #print(query_res)
    
    confs = [int(conf_inst[0]) for conf_inst in query_res if conf_inst[0]]
    #print(confs)
    median_conf = calc_median(confs)
    
    df.loc[df['Question ID'] == q_id, ['Median Confidence']] = median_conf

# %%
for q_id in q_ids:
    cur.execute("""
        SELECT question_timings->%s->'total_focus', question_timings->%s->'total_blur'
        FROM api_timingsession 
        WHERE coder_email != 'davidbstein@gmail.com';
        """,[q_id,q_id,])

    query_res = cur.fetchall()

    focus_res = [timing_inst[0] for timing_inst in query_res if timing_inst[0]]
    blur_res = [timing_inst[1] for timing_inst in query_res if timing_inst[1]]

    median_focus = calc_median(focus_res)
    median_blur = calc_median(blur_res)
    
    df.loc[df['Question ID'] == q_id, ['Median Focus']] = median_focus
    df.loc[df['Question ID'] == q_id, ['Median Blur']] = median_blur

# %%
def did_mediate(response_arr): 
    none_filter = [item for item in response_arr if item[0]]

    if len(none_filter) == 0:
        return False
    else: 
        return True

# %%
for q_id in q_ids:
    cur.execute("""
        SELECT coding_values->%s->'values'
        FROM api_codinginstance
        WHERE coder_email = 'florencia.m.wurgler@gmail.com'; 
        """,[q_id,])
    
    query_res = cur.fetchall()
    #print(query_res)
    
    fmw = did_mediate(query_res)
    #print(fmw)
    
    df.loc[df['Question ID'] == q_id, ['FMW']] = fmw

# %%
df
# Out:
#                              Label   Question ID  \
# 0                             CCPA  v72.1_2020.1
# 1                             CCPA  v72.1_2020.1
# 2                             CCPA  v72.1_2020.1
# 3                             CCPA  v72.2_2020.1
# 4                             CCPA  v72.2_2020.1
# ..                             ...           ...
# 202  [Skip me!] Notice of Contract   v2.3_2020.1
# 203  [Skip me!] Notice of Contract   v2.3_2020.1
# 204  [Skip me!] Notice of Contract   v2.4_2020.1
# 205  [Skip me!] Notice of Contract   v2.4_2020.1
# 206  [Skip me!] Notice of Contract   v2.4_2020.1
#
#                                          Question Text  \
# 0    Is the CCPA section in a separate link (as opp...
# 1    Is the CCPA section in a separate link (as opp...
# 2    Is the CCPA section in a separate link (as opp...
# 3    Does PP states firms' CCPA policy only applies...
# 4    Does PP states firms' CCPA policy only applies...
# ..                                                 ...
# 202  Are users asked to manifest unambiguous consen...
# 203  Are users asked to manifest unambiguous consen...
# 204  Are users given the option of withdrawing thei...
# 205  Are users given the option of withdrawing thei...
# 206  Are users given the option of withdrawing thei...
#
#                                      Question Response Answer Value  Count  \
# 0         [0] no, it's part of the same privacy policy            0      7
# 1    [1] yes, it's on a separate link or separate d...            1     10
# 2    [.] N/A -there is no CCPA section or CCPA refe...            .      6
# 3                                              [0] no,            0      9
# 4                                             [1] yes,            1      8
# ..                                                 ...          ...    ...
# 202                                                yes            1      0
# 203                                              other            2      0
# 204                                                 no            0      0
# 205  yes, and the clause provides an existence of t...            1      0
# 206  yes, but the clause offers only incomplete inf...            2      0
#
#      Median Confidence  Median Focus  Median Blur    FMW
# 0                  5.0       28680.0      18158.0   True
# 1                  5.0       28680.0      18158.0   True
# 2                  5.0       28680.0      18158.0   True
# 3                  4.0       17838.0      39932.0   True
# 4                  4.0       17838.0      39932.0   True
# ..                 ...           ...          ...    ...
# 202                0.0           0.0          0.0  False
# 203                0.0           0.0          0.0  False
# 204                0.0           0.0          0.0  False
# 205                0.0           0.0          0.0  False
# 206                0.0           0.0          0.0  False
#
# [207 rows x 10 columns]

# %%
df.to_csv("coding_stats.csv", index=False)
